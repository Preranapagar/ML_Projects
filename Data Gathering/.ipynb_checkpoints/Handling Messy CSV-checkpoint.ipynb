# %% [markdown]
# ## Handling messy csv file using pandas

# %%
import pandas as pd

# %%
filepath = "data/EQUITY_L.csv"
df = pd.read_csv(filepath)

# %%
df
# Out:
#                                                                                                                                                   This  \
# SYMBOL                      NAME OF COMPANY                           SERIES  DATE OF LISTING  PAID UP VALUE  MARKET LOT  ISIN NUMBER  FACE VALUE  NaN
# 20MICRONS                   20 Microns Limited                       EQ      06-Oct-08        5              1           INE144J01027 5            .NS
# 21STCENMGM                  21st Century Management Services Limited EQ      03-May-95        10             1           INE253B01015 10           .NS
# 3IINFOTECH                  3i Infotech Limited                      EQ      22-Apr-05        10             1           INE748C01020 10           .NS
# 3MINDIA                     3M India Limited                         EQ      13-Aug-04        10             1           INE470A01017 10           .NS
# ...

# %%
df.head()
# Out:
#                                                                                                                                  This  \
# SYMBOL     NAME OF COMPANY                           SERIES  DATE OF LISTING  PAID UP VALUE  MARKET LOT  ISIN NUMBER  FACE VALUE  NaN
# 20MICRONS  20 Microns Limited                       EQ      06-Oct-08        5              1           INE144J01027 5            .NS
# 21STCENMGM 21st Century Management Services Limited EQ      03-May-95        10             1           INE253B01015 10           .NS
# 3IINFOTECH 3i Infotech Limited                      EQ      22-Apr-05        10             1           INE748C01020 10           .NS
# 3MINDIA    3M India Limited                         EQ      13-Aug-04        10             1           INE470A01017 10           .NS
#
#                                                                                                                                             is   \
# ...

# %%
df.tail()
# Out:
#                                                                                                 This  \
# ZOTA                        Zota Health Care LImited     EQ  19-Aug-19 10  1   INE358U01012 10   .NS
# ZUARI                       Zuari Agro Chemicals Limited EQ  27-Nov-12 10  1   INE840M01016 10   .NS
# ZUARIGLOB                   Zuari Global Limited         BE  12-Apr-95 10  1   INE217A01012 10   .NS
# ZYDUSWELL                   Zydus Wellness Limited       EQ  13-Nov-09 10  1   INE768C01010 10   .NS
# This is the end of the file NaN                          NaN NaN       NaN NaN NaN          NaN  NaN
#
#                                                                                                           is   \
# ZOTA                        Zota Health Care LImited     EQ  19-Aug-19 10  1   INE358U01012 10        ZOTA.NS
# ZUARI                       Zuari Agro Chemicals Limited EQ  27-Nov-12 10  1   INE840M01016 10       ZUARI.NS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1667 entries, ('SYMBOL', 'NAME OF COMPANY', ' SERIES', ' DATE OF LISTING', ' PAID UP VALUE', ' MARKET LOT', ' ISIN NUMBER', ' FACE VALUE') to ('This is the end of the file', nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   This     1665 non-null   object
#  1    is      1666 non-null   object
#  2    a file  1666 non-null   object
# dtypes: object(3)
# memory usage: 333.7+ KB

# %%
df.index
# Out:
# MultiIndex([(                     'SYMBOL', ...),
#             (                  '20MICRONS', ...),
#             (                 '21STCENMGM', ...),
#             (                 '3IINFOTECH', ...),
#             (                    '3MINDIA', ...),
#             (                     '3PLAND', ...),
#             (                     '5PAISA', ...),
#             (                    '63MOONS', ...),
#             (                    '8KMILES', ...),
#             (                   'A2ZINFRA', ...),
#             ...
#             (                 'ZENSARTECH', ...),
#             (                     'ZENTEC', ...),
#             (                      'ZICOM', ...),
#             (                 'ZODIACLOTH', ...),
#             (                  'ZODJRDMKJ', ...),
#             (                       'ZOTA', ...),
#             (                      'ZUARI', ...),
#             (                  'ZUARIGLOB', ...),
# ...

# %% [markdown]
# * Header is not appropriate
# * Multiple index are present

# %% [markdown]
# #### <span style = 'color:blue'/> 1. Reset the header to row 1</span>

# %%
df = pd.read_csv(filepath, header=1)
df.head()
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2  3IINFOTECH                       3i Infotech Limited      EQ
# 3     3MINDIA                          3M India Limited      EQ
# 4      3PLAND                  3P Land Holdings Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE  \
# 0        06-Oct-08             5.0          1.0  INE144J01027          5.0
# 1        03-May-95            10.0          1.0  INE253B01015         10.0
# 2        22-Apr-05            10.0          1.0  INE748C01020         10.0
# 3        13-Aug-04            10.0          1.0  INE470A01017         10.0
# 4        19-Jul-95             2.0          1.0  INE105C01023          2.0
#
#   Unnamed: 8     YahooEquiv Yahoo_Equivalent_Code
# 0        .NS   20MICRONS.NS       '20MICRONS.NS',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1666, step=1)

# %%
df.tail()
# Out:
#                            SYMBOL               NAME OF COMPANY  SERIES  \
# 1661                         ZOTA      Zota Health Care LImited      EQ
# 1662                        ZUARI  Zuari Agro Chemicals Limited      EQ
# 1663                    ZUARIGLOB          Zuari Global Limited      BE
# 1664                    ZYDUSWELL        Zydus Wellness Limited      EQ
# 1665  This is the end of the file                           NaN     NaN
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE  \
# 1661        19-Aug-19            10.0          1.0  INE358U01012         10.0
# 1662        27-Nov-12            10.0          1.0  INE840M01016         10.0
# 1663        12-Apr-95            10.0          1.0  INE217A01012         10.0
# 1664        13-Nov-09            10.0          1.0  INE768C01010         10.0
# 1665              NaN             NaN          NaN           NaN          NaN
#
#      Unnamed: 8    YahooEquiv Yahoo_Equivalent_Code
# ...

# %% [markdown]
# #### <span style = 'color:blue'/> 2. Drop the last row</span>

# %%
df.drop(index=1665, axis=0, inplace=True)

# %%
df
# Out:
#                            SYMBOL                           NAME OF COMPANY  \
# 0                       20MICRONS                        20 Microns Limited
# 1                      21STCENMGM  21st Century Management Services Limited
# 2                      3IINFOTECH                       3i Infotech Limited
# 3                         3MINDIA                          3M India Limited
# 4                          3PLAND                  3P Land Holdings Limited
# ...                           ...                                       ...
# 1661                         ZOTA                  Zota Health Care LImited
# 1662                        ZUARI              Zuari Agro Chemicals Limited
# 1663                    ZUARIGLOB                      Zuari Global Limited
# 1664                    ZYDUSWELL                    Zydus Wellness Limited
# 1665  This is the end of the file                                       NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# SYMBOL                   0
# NAME OF COMPANY          0
#  SERIES                  0
#  DATE OF LISTING         0
#  PAID UP VALUE           0
#  MARKET LOT              0
#  ISIN NUMBER             0
#  FACE VALUE              0
# Unnamed: 8               0
# YahooEquiv               0
# Yahoo_Equivalent_Code    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['SYMBOL', 'NAME OF COMPANY', ' SERIES', ' DATE OF LISTING',
#        ' PAID UP VALUE', ' MARKET LOT', ' ISIN NUMBER', ' FACE VALUE',
#        'Unnamed: 8', 'YahooEquiv', 'Yahoo_Equivalent_Code'],
#       dtype='object')

# %% [markdown]
# #### <span style = 'color:blue'/> 3. Performing all operation while reading the data</span>

# %%
col_name = ['Symbol','Company','Series','Listing_Date','Paid_up_Value','Market_Lot','ISIN_Number','Face_Value',
           'Unanamed','Yahoo_Equiv','Yahoo_Equivalent_Code']

# %%
df2 = pd.read_csv(filepath,skiprows=2, skipfooter=1, header=None, names=col_name)
# Out:
# C:\Users\Prerana\AppData\Local\Temp\ipykernel_27808\3157188525.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv(filepath,skiprows=2, skipfooter=1, header=None, names=col_name)

# %%
df2.head()
# Out:
#        Symbol                                   Company Series Listing_Date  \
# 0   20MICRONS                        20 Microns Limited     EQ    06-Oct-08
# 1  21STCENMGM  21st Century Management Services Limited     EQ    03-May-95
# 2  3IINFOTECH                       3i Infotech Limited     EQ    22-Apr-05
# 3     3MINDIA                          3M India Limited     EQ    13-Aug-04
# 4      3PLAND                  3P Land Holdings Limited     EQ    19-Jul-95
#
#    Paid_up_Value  Market_Lot   ISIN_Number  Face_Value Unanamed  \
# 0              5           1  INE144J01027           5      .NS
# 1             10           1  INE253B01015          10      .NS
# 2             10           1  INE748C01020          10      .NS
# 3             10           1  INE470A01017          10      .NS
# 4              2           1  INE105C01023           2      .NS
#
#      Yahoo_Equiv Yahoo_Equivalent_Code
# 0   20MICRONS.NS       '20MICRONS.NS',
# 1  21STCENMGM.NS      '21STCENMGM.NS',
# ...

# %%
df2.tail()
# Out:
#          Symbol                       Company Series Listing_Date  \
# 1660  ZODJRDMKJ       Zodiac JRD- MKJ Limited     EQ    19-Jul-95
# 1661       ZOTA      Zota Health Care LImited     EQ    19-Aug-19
# 1662      ZUARI  Zuari Agro Chemicals Limited     EQ    27-Nov-12
# 1663  ZUARIGLOB          Zuari Global Limited     BE    12-Apr-95
# 1664  ZYDUSWELL        Zydus Wellness Limited     EQ    13-Nov-09
#
#       Paid_up_Value  Market_Lot   ISIN_Number  Face_Value Unanamed  \
# 1660             10           1  INE077B01018          10      .NS
# 1661             10           1  INE358U01012          10      .NS
# 1662             10           1  INE840M01016          10      .NS
# 1663             10           1  INE217A01012          10      .NS
# 1664             10           1  INE768C01010          10      .NS
#
#        Yahoo_Equiv Yahoo_Equivalent_Code
# 1660  ZODJRDMKJ.NS       'ZODJRDMKJ.NS',
# 1661       ZOTA.NS            'ZOTA.NS',
# ...

# %% [markdown]
# **END**
