# %%
# Performing EDA using DABL (Data analysis baseline library)

# %%
import pandas as pd
import numpy as np
import dabl
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('RTA Dataset.csv')

# %%
df_clean=dabl.clean(df,verbose=0)

# %%
types=dabl.detect_types(df_clean)
print(types)
# Out:
#                                       continuous  dirty_float  \
# Time                                       False        False
# Day_of_week                                False        False
# Age_band_of_driver                         False        False
# Sex_of_driver                              False        False
# Educational_level                          False        False
# Vehicle_driver_relation                    False        False
# Driving_experience                         False        False
# Type_of_vehicle                            False        False
# Owner_of_vehicle                           False        False
# Service_year_of_vehicle                    False        False
# Area_accident_occured                      False        False
# Lanes_or_Medians                           False        False
# Road_allignment                            False        False
# Types_of_Junction                          False        False
# ...

# %%
dabl.plot(df,'Accident_severity')
# Out:
# C:\Users\Prerana\anaconda3\lib\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Showing only top 10 of 32 categorical features
# [<AxesSubplot:title={'center':'Target distribution'}, xlabel='count', ylabel='Accident_severity'>,
#  None,
#  array([[<AxesSubplot:title={'center':'Number_of_vehicles_involved'}>,
#          <AxesSubplot:title={'center':'Number_of_casualties'}>,
#          <AxesSubplot:title={'center':'Types_of_Junction'}>,
#          <AxesSubplot:title={'center':'Age_band_of_driver'}>,
#          <AxesSubplot:title={'center':'Weather_conditions'}>],
#         [<AxesSubplot:title={'center':'Type_of_vehicle'}>,
#          <AxesSubplot:title={'center':'Area_accident_occured'}>,
#          <AxesSubplot:title={'center':'Cause_of_accident'}>,
# ...
